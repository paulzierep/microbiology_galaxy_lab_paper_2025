# %% [markdown]
# # Imports

# %%
import pandas as pd
import seaborn as sns
from owlready2 import get_ontology, Thing
import matplotlib.pyplot as plt
import copy
import numpy as np
from adjustText import adjust_text
from googleapiclient.discovery import build
from datetime import timedelta
import isodate
# Out:
# Warning: SQLite3 version 3.40.0 and 3.41.2 have huge performance regressions; please install version 3.41.1 or 3.42!

# %% [markdown]
# # Getting Data from CoDex

# %%
tutorials_url = "../docs/supplementary/supplementary_table_6.tsv"
tools_url = "../docs/supplementary/supplementary_table_2.tsv"
workflows_url = "../docs/supplementary/supplementary_table_4.tsv"

tutorials_df = pd.read_csv(tutorials_url, sep="\t")
tutorials_df = tutorials_df.drop_duplicates(keep="last")

tools_df = pd.read_csv(tools_url, sep="\t")

workflows_df = pd.read_csv(workflows_url, sep="\t")

# %% [markdown]
# # Set up your API key

# %%
API_KEY = ''  # Replace with your  youtube API key
youtube = build('youtube', 'v3', developerKey=API_KEY)

# %% [markdown]
# # Tutorials Statistics

# %% [markdown]
# ## Create new rows, one row for each EDAM term per tutorial

# %% [markdown]
# #### EDAM Operations

# %%
inflated_tutorials_operation = []
for idx, row in tutorials_df.iterrows():
    terms = row["EDAM operation"]
    row_d = row.to_dict()
    if isinstance(terms, str):
        vals = [t.strip() for t in terms.split(",")]
        for val in vals:
            row_c = copy.copy(row_d)
            row_c["EDAM operation single"] = val
            inflated_tutorials_operation.append(row_c)
    else:
        row_c = copy.copy(row_d)
        row_c["EDAM operation single"] = "Undefined"
        inflated_tutorials_operation.append(row_c)

df_inflated_tutorials_operation = pd.DataFrame(inflated_tutorials_operation)

df_inflated_tutorials_operation.head()
# Out:
#       Topic                                              Title  \
# 0  Assembly  Genome Assembly of a bacterial genome (MRSA) s...
# 1  Assembly  Genome Assembly of a bacterial genome (MRSA) s...
# 2  Assembly  Genome Assembly of a bacterial genome (MRSA) s...
# 3  Assembly  Genome Assembly of a bacterial genome (MRSA) s...
# 4  Assembly  Genome Assembly of a bacterial genome (MRSA) s...
#
#                                                 Link  \
# 0  https://training.galaxyproject.org//topics/ass...
# 1  https://training.galaxyproject.org//topics/ass...
# 2  https://training.galaxyproject.org//topics/ass...
# 3  https://training.galaxyproject.org//topics/ass...
# 4  https://training.galaxyproject.org//topics/ass...
#
#                                           EDAM topic  \
# 0  Sequence assembly, Whole genome sequencing, Pu...
# 1  Sequence assembly, Whole genome sequencing, Pu...
# 2  Sequence assembly, Whole genome sequencing, Pu...
# 3  Sequence assembly, Whole genome sequencing, Pu...
# 4  Sequence assembly, Whole genome sequencing, Pu...
#
#                                       EDAM operation    Creation  \
# 0  Sequence assembly visualisation, Genome assemb...  2021-03-24
# 1  Sequence assembly visualisation, Genome assemb...  2021-03-24
# 2  Sequence assembly visualisation, Genome assemb...  2021-03-24
# 3  Sequence assembly visualisation, Genome assemb...  2021-03-24
# 4  Sequence assembly visualisation, Genome assemb...  2021-03-24
#
#   Last modification  Version Tutorial  Slides  ...  \
# 0        2025-03-20       16     True   False  ...
# 1        2025-03-20       16     True   False  ...
# 2        2025-03-20       16     True   False  ...
# 3        2025-03-20       16     True   False  ...
# 4        2025-03-20       16     True   False  ...
#
#                                                Tools  \
# 0  fastp, quast, fastqc, shovill, upload1, bandag...
# 1  fastp, quast, fastqc, shovill, upload1, bandag...
# 2  fastp, quast, fastqc, shovill, upload1, bandag...
# 3  fastp, quast, fastqc, shovill, upload1, bandag...
# 4  fastp, quast, fastqc, shovill, upload1, bandag...
#
#                   Servers with precise tool versions  \
# 0  UseGalaxy.be, UseGalaxy.cz, UseGalaxy.eu, UseG...
# 1  UseGalaxy.be, UseGalaxy.cz, UseGalaxy.eu, UseG...
# 2  UseGalaxy.be, UseGalaxy.cz, UseGalaxy.eu, UseG...
# 3  UseGalaxy.be, UseGalaxy.cz, UseGalaxy.eu, UseG...
# 4  UseGalaxy.be, UseGalaxy.cz, UseGalaxy.eu, UseG...
#
#   Servers with tool but different versions Feedback number Feedback mean note  \
# 0                                      NaN               0                NaN
# 1                                      NaN               0                NaN
# 2                                      NaN               0                NaN
# 3                                      NaN               0                NaN
# 4                                      NaN               0                NaN
#
#    Visitors  Page views  Visit duration  Video views  \
# 0      9642       14954            3.65            0
# 1      9642       14954            3.65            0
# 2      9642       14954            3.65            0
# 3      9642       14954            3.65            0
# 4      9642       14954            3.65            0
#
#               EDAM operation single
# 0   Sequence assembly visualisation
# 1                   Genome assembly
# 2           Statistical calculation
# 3  Sequence contamination filtering
# 4  Sequence composition calculation
#
# [5 rows x 22 columns]

# %% [markdown]
# #### EDAM topics

# %%
inflated_tutorials_topics = []
for idx, row in tutorials_df.iterrows():
    terms = row["EDAM topic"]
    row_d = row.to_dict()
    if isinstance(terms, str):
        vals = [t.strip() for t in terms.split(",")]
        for val in vals:
            row_c = copy.copy(row_d)
            row_c["EDAM topic single"] = val
            inflated_tutorials_topics.append(row_c)
    else:
        row_c = copy.copy(row_d)
        row_c["EDAM topic single"] = "Undefined"
        inflated_tutorials_topics.append(row_c)

df_inflated_tutorials_topics = pd.DataFrame(inflated_tutorials_topics)

df_inflated_tutorials_topics.head()
# Out:
#       Topic                                              Title  \
# 0  Assembly  Genome Assembly of a bacterial genome (MRSA) s...
# 1  Assembly  Genome Assembly of a bacterial genome (MRSA) s...
# 2  Assembly  Genome Assembly of a bacterial genome (MRSA) s...
# 3  Assembly  Genome Assembly of a bacterial genome (MRSA) s...
# 4  Assembly  Genome Assembly of a bacterial genome (MRSA) s...
#
#                                                 Link  \
# 0  https://training.galaxyproject.org//topics/ass...
# 1  https://training.galaxyproject.org//topics/ass...
# 2  https://training.galaxyproject.org//topics/ass...
# 3  https://training.galaxyproject.org//topics/ass...
# 4  https://training.galaxyproject.org//topics/ass...
#
#                                           EDAM topic  \
# 0  Sequence assembly, Whole genome sequencing, Pu...
# 1  Sequence assembly, Whole genome sequencing, Pu...
# 2  Sequence assembly, Whole genome sequencing, Pu...
# 3  Sequence assembly, Whole genome sequencing, Pu...
# 4  Sequence assembly, Whole genome sequencing, Pu...
#
#                                       EDAM operation    Creation  \
# 0  Sequence assembly visualisation, Genome assemb...  2021-03-24
# 1  Sequence assembly visualisation, Genome assemb...  2021-03-24
# 2  Sequence assembly visualisation, Genome assemb...  2021-03-24
# 3  Sequence assembly visualisation, Genome assemb...  2021-03-24
# 4  Sequence assembly visualisation, Genome assemb...  2021-03-24
#
#   Last modification  Version Tutorial  Slides  ...  \
# 0        2025-03-20       16     True   False  ...
# 1        2025-03-20       16     True   False  ...
# 2        2025-03-20       16     True   False  ...
# 3        2025-03-20       16     True   False  ...
# 4        2025-03-20       16     True   False  ...
#
#                                                Tools  \
# 0  fastp, quast, fastqc, shovill, upload1, bandag...
# 1  fastp, quast, fastqc, shovill, upload1, bandag...
# 2  fastp, quast, fastqc, shovill, upload1, bandag...
# 3  fastp, quast, fastqc, shovill, upload1, bandag...
# 4  fastp, quast, fastqc, shovill, upload1, bandag...
#
#                   Servers with precise tool versions  \
# 0  UseGalaxy.be, UseGalaxy.cz, UseGalaxy.eu, UseG...
# 1  UseGalaxy.be, UseGalaxy.cz, UseGalaxy.eu, UseG...
# 2  UseGalaxy.be, UseGalaxy.cz, UseGalaxy.eu, UseG...
# 3  UseGalaxy.be, UseGalaxy.cz, UseGalaxy.eu, UseG...
# 4  UseGalaxy.be, UseGalaxy.cz, UseGalaxy.eu, UseG...
#
#   Servers with tool but different versions Feedback number Feedback mean note  \
# 0                                      NaN               0                NaN
# 1                                      NaN               0                NaN
# 2                                      NaN               0                NaN
# 3                                      NaN               0                NaN
# 4                                      NaN               0                NaN
#
#    Visitors  Page views  Visit duration  Video views  \
# 0      9642       14954            3.65            0
# 1      9642       14954            3.65            0
# 2      9642       14954            3.65            0
# 3      9642       14954            3.65            0
# 4      9642       14954            3.65            0
#
#                 EDAM topic single
# 0               Sequence assembly
# 1         Whole genome sequencing
# 2  Public health and epidemiology
# 3                        Genomics
# 4                    Microbiology
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Statistics

# %%
unique_tutorials = tutorials_df["Title"].nunique()
df2 = tutorials_df.drop_duplicates(subset='Title', keep="last")
unique_operations = df_inflated_tutorials_operation["EDAM operation single"].nunique()
unique_topics = df_inflated_tutorials_topics["EDAM topic single"].nunique()

# Count videos and workflows per tutorial with additional checks for string type
df2["Video Count"] = df2["Video"].apply(lambda x: len(x.split(',')) if isinstance(x, str) and x.strip() else 0)
df2["Workflow Count"] = df2["Workflows"].apply(lambda x: len(x.split(',')) if isinstance(x, str) and x.strip() else 0)

# Calculate tutorials with associated videos and workflows (count of True values in each column)
tutorials_with_videos = df2["Video"].sum()
tutorials_with_workflows = df2["Workflows"].sum()

# Calculate the total number of videos and workflows
total_videos = df2[df2["Video"] == True].shape[0]  # Total number of True values in Video column
total_workflows = df2[df2["Workflows"] == True].shape[0]  # Total number of True values in Workflows column

# Calculate percentages
percentage_with_videos = (tutorials_with_videos / unique_tutorials) * 100
percentage_with_workflows = (tutorials_with_workflows / unique_tutorials) * 100

# Print statistics
print(f"Total number of unique tutorials: {unique_tutorials}")
print(f"Total number of unique EDAM operations: {unique_operations}")
print(f"Total number of unique EDAM topics: {unique_topics}")
print(f"Total number of unique tutorials: {unique_tutorials}")
print(f"Total number of tutorials with associated videos: {tutorials_with_videos}")
print(f"Percentage of tutorials with videos: {percentage_with_videos:.2f}%")
print(f"Total number of videos: {total_videos}")

print(f"Total number of tutorials with associated workflows: {tutorials_with_workflows}")
print(f"Percentage of tutorials with workflows: {percentage_with_workflows:.2f}%")
print(f"Total number of workflows: {total_workflows}")
# Out:
# Total number of unique tutorials: 39
# Total number of unique EDAM operations: 86
# Total number of unique EDAM topics: 26
# Total number of unique tutorials: 39
# Total number of tutorials with associated videos: 18
# Percentage of tutorials with videos: 46.15%
# Total number of videos: 18
# Total number of tutorials with associated workflows: 33
# Percentage of tutorials with workflows: 84.62%
# Total number of workflows: 33
# /tmp/ipykernel_36844/3973245857.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Video Count"] = df2["Video"].apply(lambda x: len(x.split(',')) if isinstance(x, str) and x.strip() else 0)
# /tmp/ipykernel_36844/3973245857.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Workflow Count"] = df2["Workflows"].apply(lambda x: len(x.split(',')) if isinstance(x, str) and x.strip() else 0)

# %% [markdown]
# ## Tutorials Videos on Youtube

# %%
# Function to get video duration using YouTube API
def get_video_duration_api(video_url):
    try:
        # Extract the video ID from the URL
        video_id = video_url.split('v=')[-1].split('&')[0] if 'youtube' in video_url else video_url.split('/')[-1]
        request = youtube.videos().list(part="contentDetails", id=video_id)
        response = request.execute()

        # Extract duration in ISO 8601 format
        items = response.get("items")
        if items:
            duration = items[0]["contentDetails"]["duration"]
            # Convert ISO 8601 to total seconds
            return parse_iso_duration(duration)
        else:
            print(f"No details found for video: {video_url}")
            return 0
    except Exception as e:
        print(f"Error processing video {video_url}: {e}")
        return 0

# Function to parse ISO 8601 duration to seconds

def parse_iso_duration(duration):
    duration_obj = isodate.parse_duration(duration)
    return int(duration_obj.total_seconds())

# Load the table containing YouTube links
file_path = 'tutorialsYoutube/tutorialsVideos.csv'
df = pd.read_csv(file_path)

# Column containing YouTube links
column_name = "Video_Link"

# Apply function to get video durations
print("Fetching video durations...\n")
df['Duration_seconds'] = df[column_name].apply(get_video_duration_api)

# Calculate total duration
total_duration_seconds = int(df['Duration_seconds'].sum())  # Convert to Python int
total_duration = timedelta(seconds=total_duration_seconds)

# Display the total duration
print("\nSummary of Video Durations:")
print(f"Total number of unique videos: {len(df)}")
print(f"Total duration (hh:mm:ss): {total_duration}")

# Save updated table
output_file = "tutorialsYoutube/table_with_api_video_durations.csv"
df.to_csv(output_file, index=False)
print(f"Updated table saved to {output_file}")
# Out:
# Fetching video durations...
#
#
# Summary of Video Durations:
# Total number of unique videos: 17
# Total duration (hh:mm:ss): 15:42:09
# Updated table saved to tutorialsYoutube/table_with_api_video_durations.csv

# %% [markdown]
# # Tools Statistics

# %% [markdown]
# ## Create new rows, one row for each EDAM term per tool

# %% [markdown]
# ### EDAM Operation

# %%
inflated_tools = []

for idx, row in tools_df.iterrows():
    terms = row["EDAM reduced operations"]
    row_d = row.to_dict()
    if isinstance(terms, str):
        vals = [t.strip() for t in terms.split(",")]
        for val in vals:
            row_c = copy.copy(row_d)
            row_c["EDAM operation single"] = val
            inflated_tools.append(row_c)
    else:
            row_c = copy.copy(row_d)
            row_c["EDAM operation single"] = "Undefined"
            inflated_tools.append(row_c)

df_inflated_tools_operation = pd.DataFrame(inflated_tools)

# %% [markdown]
# ### EDAM Topics

# %%
inflated_tools = []

for idx, row in tools_df.iterrows():
    terms = row["EDAM reduced topics"]
    row_d = row.to_dict()
    if isinstance(terms, str):
        vals = [t.strip() for t in terms.split(",")]
        for val in vals:
            row_c = copy.copy(row_d)
            row_c["EDAM topic single"] = val
            inflated_tools.append(row_c)
    else:
            row_c = copy.copy(row_d)
            row_c["EDAM topic single"] = "Undefined"
            inflated_tools.append(row_c)

df_inflated_tools_topics = pd.DataFrame(inflated_tools)

# %% [markdown]
# ### Tools not suites

# %%
inflated_tools = []

for idx, row in tools_df.iterrows():
    terms = row["Tool IDs"]
    row_d = row.to_dict()
    if isinstance(terms, str):
        vals = [t.strip() for t in terms.split(",")]
        for val in vals:
            row_c = copy.copy(row_d)
            row_c["tools per suite"] = val
            inflated_tools.append(row_c)
    else:
            row_c = copy.copy(row_d)
            row_c["tools per suite"] = "Undefined"
            inflated_tools.append(row_c)

df_inflated_tools_per_suite = pd.DataFrame(inflated_tools)
df_inflated_tools_per_suite
# Out:
#           Suite ID                                           Tool IDs  \
# 0    AMRFinderPlus                                      amrfinderplus
# 1          ISEScan                                            isescan
# 2           abacas                                             abacas
# 3         abricate          abricate, abricate_list, abricate_summary
# 4         abricate          abricate, abricate_list, abricate_summary
# ..             ...                                                ...
# 908        vsearch  vsearch_alignment, vsearch_chimera_detection, ...
# 909        vsearch  vsearch_alignment, vsearch_chimera_detection, ...
# 910        vsearch  vsearch_alignment, vsearch_chimera_detection, ...
# 911        vsearch  vsearch_alignment, vsearch_chimera_detection, ...
# 912          wtdbg                                              wtdbg
#
#                                            Description  \
# 0    "AMRFinderPlus is designed to find acquired an...
# 1    "ISEScan is a pipeline to identify IS (Inserti...
# 2                          Order and Orientate Contigs
# 3    Mass screening of contigs for antiobiotic resi...
# 4    Mass screening of contigs for antiobiotic resi...
# ..                                                 ...
# 908  VSEARCH including searching, clustering, chime...
# 909  VSEARCH including searching, clustering, chime...
# 910  VSEARCH including searching, clustering, chime...
# 911  VSEARCH including searching, clustering, chime...
# 912  WTDBG is a fuzzy Bruijn graph (FBG) approach t...
#
#     Suite first commit date                              Homepage  \
# 0                2023-05-12           https://github.com/ncbi/amr
# 1                2022-09-01     https://github.com/xiezhq/ISEScan
# 2                2019-11-20    https://github.com/phac-nml/abacas
# 3                2016-07-29  https://github.com/tseemann/abricate
# 4                2016-07-29  https://github.com/tseemann/abricate
# ..                      ...                                   ...
# 908              2014-11-30   https://github.com/torognes/vsearch
# 909              2014-11-30   https://github.com/torognes/vsearch
# 910              2014-11-30   https://github.com/torognes/vsearch
# 911              2014-11-30   https://github.com/torognes/vsearch
# 912              2018-06-12     https://github.com/ruanjue/wtdbg2
#
#     Suite version Suite conda package Latest suite conda package version  \
# 0          3.12.8  ncbi-amrfinderplus                             4.0.23
# 1           1.7.3             isescan                              1.7.3
# 2             1.1              mummer                               3.23
# 3           1.0.1            abricate                              1.0.1
# 4           1.0.1            abricate                              1.0.1
# ..            ...                 ...                                ...
# 908         2.8.3             vsearch                             2.30.0
# 909         2.8.3             vsearch                             2.30.0
# 910         2.8.3             vsearch                             2.30.0
# 911         2.8.3             vsearch                             2.30.0
# 912           2.5               wtdbg                                2.5
#
#     Suite version status ToolShed categories  ... Suite runs (usegalaxy.fr)  \
# 0              To update   Sequence Analysis  ...                      1863
# 1             Up-to-date   Sequence Analysis  ...                      1759
# 2              To update            Assembly  ...                         3
# 3             Up-to-date   Sequence Analysis  ...                     19178
# 4             Up-to-date   Sequence Analysis  ...                     19178
# ..                   ...                 ...  ...                       ...
# 908            To update   Sequence Analysis  ...                       286
# 909            To update   Sequence Analysis  ...                       286
# 910            To update   Sequence Analysis  ...                       286
# 911            To update   Sequence Analysis  ...                       286
# 912           Up-to-date            Assembly  ...                       145
#
#     Suite runs on main servers Suite runs (last 5 years) on main servers  \
# 0                        64355                                     64355
# 1                        78274                                     78274
# 2                            3                                         3
# 3                      1846906                                   1798743
# 4                      1846906                                   1798743
# ..                         ...                                       ...
# 908                      83368                                     35354
# 909                      83368                                     35354
# 910                      83368                                     35354
# 911                      83368                                     35354
# 912                       2049                                      1458
#
#     Suite users on main servers Suite users (last 5 years) on main servers  \
# 0                          1670                                       1670
# 1                           782                                        782
# 2                             2                                          2
# 3                         10448                                       9875
# 4                         10448                                       9875
# ..                          ...                                        ...
# 908                        1010                                        642
# 909                        1010                                        642
# 910                        1010                                        642
# 911                        1010                                        642
# 912                         479                                        394
#
#                                      Related Workflows  \
# 0    https://usegalaxy.eu/published/workflow?id=1ce...
# 1    https://usegalaxy.eu/published/workflow?id=2c1...
# 2                                                  NaN
# 3    https://usegalaxy.eu/published/workflow?id=1ce...
# 4    https://usegalaxy.eu/published/workflow?id=1ce...
# ..                                                 ...
# 908  https://usegalaxy.eu/published/workflow?id=401...
# 909  https://usegalaxy.eu/published/workflow?id=401...
# 910  https://usegalaxy.eu/published/workflow?id=401...
# 911  https://usegalaxy.eu/published/workflow?id=401...
# 912                                                NaN
#
#                                      Related Tutorials To keep Deprecated  \
# 0                                                  NaN    True      False
# 1        genome-annotation/bacterial-genome-annotation    True      False
# 2                                                  NaN    True      False
# 3    microbiome/pathogen-detection-from-nanopore-fo...    True      False
# 4    microbiome/pathogen-detection-from-nanopore-fo...    True      False
# ..                                                 ...     ...        ...
# 908                                                NaN    True      False
# 909                                                NaN    True      False
# 910                                                NaN    True      False
# 911                                                NaN    True      False
# 912                                                NaN    True      False
#
#        tools per suite
# 0        amrfinderplus
# 1              isescan
# 2               abacas
# 3             abricate
# 4        abricate_list
# ..                 ...
# 908    vsearch_masking
# 909     vsearch_search
# 910  vsearch_shuffling
# 911    vsearch_sorting
# 912              wtdbg
#
# [913 rows x 75 columns]

# %% [markdown]
# ## Statistics

# %%
# Get the total number of tools
total_tools = tools_df.shape[0]

# Calculate total tool usage over the last 5 years, over all main servers
total_tool_usage = tools_df['Suite runs (last 5 years) on main servers'].sum()

# Calculate total number of tool users over the last 5 years, over all main servers
total_tool_users = tools_df['Suite users (last 5 years) on main servers'].sum()

# Calculate the average number of tool users over the last 5 years, over all main servers
average_tool_users = tools_df['Suite users (last 5 years) on main servers'].mean()

# Find the most used tool over the last 5 years, over all main servers
most_used_tool = tools_df.loc[tools_df['Suite runs (last 5 years) on main servers'].idxmax()]

# Find the tool with the most used over the last 5 years, over all main servers
most_users_tool = tools_df.loc[tools_df['Suite users (last 5 years) on main servers'].idxmax()]

total_tools, total_tool_usage, total_tool_users, average_tool_users, most_used_tool, most_users_tool
# Out:
# (320,
#  25164728,
#  766510,
#  2395.34375,
#  Suite ID                                                                                  fastp
#  Tool IDs                                                                                  fastp
#  Description                                       Fast all-in-one preprocessing for FASTQ files
#  Suite first commit date                                                              2018-03-07
#  Homepage                                                      https://github.com/OpenGene/fastp
#                                                                      ...
#  Suite users (last 5 years) on main servers                                                27815
#  Related Workflows                             https://usegalaxy.eu/published/workflow?id=007...
#  Related Tutorials                             assembly/assembly-with-preprocessing, assembly...
#  To keep                                                                                    True
#  Deprecated                                                                                False
#  Name: 84, Length: 74, dtype: object,
#  Suite ID                                                                                multiqc
#  Tool IDs                                                                                multiqc
#  Description                                   MultiQC aggregates results from bioinformatics...
#  Suite first commit date                                                              2017-09-21
#  Homepage                                                                   http://multiqc.info/
#                                                                      ...
#  Suite users (last 5 years) on main servers                                                65767
#  Related Workflows                             https://usegalaxy.eu/published/workflow?id=002...
#  Related Tutorials                             assembly/assembly-with-preprocessing, assembly...
#  To keep                                                                                    True
#  Deprecated                                                                                False
#  Name: 206, Length: 74, dtype: object)

# %%
unique_tools = tools_df["Suite ID"].nunique()
unique_tools_operations = df_inflated_tools_operation["EDAM operation single"].nunique()
unique_tools_topics = df_inflated_tools_topics["EDAM topic single"].nunique()
unique_tools_per_suite = df_inflated_tools_per_suite["tools per suite"].nunique()

# Print statistics
print(f"Total number of tools: {unique_tools}")
print(f"Total number of unique EDAM operations: {unique_tools_operations}")
print(f"Total number of unique EDAM topics: {unique_tools_topics}")
print(f"Total number of unique tools: {unique_tools_per_suite}")
# Out:
# Total number of tools: 318
# Total number of unique EDAM operations: 155
# Total number of unique EDAM topics: 97
# Total number of unique tools: 910

# %% [markdown]
# # Workflows Statistics

# %% [markdown]
# ## Create new rows, one row for each EDAM term per workflow

# %% [markdown]
# ### EDAM Operation

# %%
inflated_workflows_operation = []
for idx, row in workflows_df.iterrows():
    terms = row["EDAM operations"]
    row_d = row.to_dict()
    if isinstance(terms, str):
        vals = [t.strip() for t in terms.split(",")]
        for val in vals:
            row_c = copy.copy(row_d)
            row_c["EDAM operation single"] = val
            inflated_workflows_operation.append(row_c)
    else:
        row_c = copy.copy(row_d)
        row_c["EDAM operation single"] = "Undefined"
        inflated_workflows_operation.append(row_c)

df_inflated_workflows_operation = pd.DataFrame(inflated_workflows_operation)

df_inflated_workflows_operation.head()
# Out:
#                                                 Name       Source    ID  \
# 0  bacterial-quality-and-contamination-control-po...  WorkflowHub  1882
# 1  bacterial-quality-and-contamination-control-po...  WorkflowHub  1882
# 2  bacterial-quality-and-contamination-control-po...  WorkflowHub  1882
# 3  bacterial-quality-and-contamination-control-po...  WorkflowHub  1882
# 4  bacterial-quality-and-contamination-control-po...  WorkflowHub  1882
#
#                                               Link  \
# 0  https://workflowhub.eu/workflows/1882?version=2
# 1  https://workflowhub.eu/workflows/1882?version=2
# 2  https://workflowhub.eu/workflows/1882?version=2
# 3  https://workflowhub.eu/workflows/1882?version=2
# 4  https://workflowhub.eu/workflows/1882?version=2
#
#                                     Creators Tags Creation time Update time  \
# 0  ABRomics None, Pierre Marin, Clea Siguret  NaN    2025-08-28  2025-08-28
# 1  ABRomics None, Pierre Marin, Clea Siguret  NaN    2025-08-28  2025-08-28
# 2  ABRomics None, Pierre Marin, Clea Siguret  NaN    2025-08-28  2025-08-28
# 3  ABRomics None, Pierre Marin, Clea Siguret  NaN    2025-08-28  2025-08-28
# 4  ABRomics None, Pierre Marin, Clea Siguret  NaN    2025-08-28  2025-08-28
#
#    Latest version  Versions  Number of steps  \
# 0               2         2             14.0
# 1               2         2             14.0
# 2               2         2             14.0
# 3               2         2             14.0
# 4               2         2             14.0
#
#                                                Tools  \
# 0  est_abundance, kraken2, checkm2, quast, collap...
# 1  est_abundance, kraken2, checkm2, quast, collap...
# 2  est_abundance, kraken2, checkm2, quast, collap...
# 3  est_abundance, kraken2, checkm2, quast, collap...
# 4  est_abundance, kraken2, checkm2, quast, collap...
#
#                                      EDAM operations EDAM topics  \
# 0  Cross-assembly, Taxonomic classification, Stat...         NaN
# 1  Cross-assembly, Taxonomic classification, Stat...         NaN
# 2  Cross-assembly, Taxonomic classification, Stat...         NaN
# 3  Cross-assembly, Taxonomic classification, Stat...         NaN
# 4  Cross-assembly, Taxonomic classification, Stat...         NaN
#
#             License  DOI                                 Projects  To keep  \
# 0  GPL-3.0-or-later  NaN  Intergalactic Workflow Commission (IWC)     True
# 1  GPL-3.0-or-later  NaN  Intergalactic Workflow Commission (IWC)     True
# 2  GPL-3.0-or-later  NaN  Intergalactic Workflow Commission (IWC)     True
# 3  GPL-3.0-or-later  NaN  Intergalactic Workflow Commission (IWC)     True
# 4  GPL-3.0-or-later  NaN  Intergalactic Workflow Commission (IWC)     True
#
#    Deprecated     EDAM operation single
# 0       False            Cross-assembly
# 1       False  Taxonomic classification
# 2       False   Statistical calculation
# 3       False       Expression analysis
# 4       False             Visualisation

# %% [markdown]
# ### EDAM topics

# %%
inflated_workflows_topics = []
for idx, row in workflows_df.iterrows():
    terms = row["EDAM topics"]
    row_d = row.to_dict()
    if isinstance(terms, str):
        vals = [t.strip() for t in terms.split(",")]
        for val in vals:
            row_c = copy.copy(row_d)
            row_c["EDAM topic single"] = val
            inflated_workflows_topics.append(row_c)
    else:
        row_c = copy.copy(row_d)
        row_c["EDAM topic single"] = "Undefined"
        inflated_workflows_topics.append(row_c)

df_inflated_workflows_topics = pd.DataFrame(inflated_workflows_topics)

df_inflated_workflows_topics.head()
# Out:
#                                                 Name       Source    ID  \
# 0  bacterial-quality-and-contamination-control-po...  WorkflowHub  1882
# 1  sars-cov-2-pe-illumina-artic-ivar-analysis/SAR...  WorkflowHub   155
# 2  sars-cov-2-pe-illumina-wgs-variant-calling/COV...  WorkflowHub   113
# 3   generic-non-segmented-viral-variant-calling/main  WorkflowHub  1876
# 4    influenza-isolates-consensus-and-subtyping/main  WorkflowHub  1260
#
#                                               Link  \
# 0  https://workflowhub.eu/workflows/1882?version=2
# 1   https://workflowhub.eu/workflows/155?version=6
# 2   https://workflowhub.eu/workflows/113?version=4
# 3  https://workflowhub.eu/workflows/1876?version=1
# 4  https://workflowhub.eu/workflows/1260?version=2
#
#                                             Creators  \
# 0          ABRomics None, Pierre Marin, Clea Siguret
# 1                                  Peter van Heusden
# 2                                     Wolfgang Maier
# 3                  Peter van Heusden, Wolfgang Maier
# 4  Viktoria Isabel Schwarz, Wolfgang Maier, Aaron...
#
#                                                 Tags Creation time  \
# 0                                                NaN    2025-08-28
# 1                                           virology    2025-07-31
# 2  virology, covid-19, covid19.galaxyproject.org,...    2021-12-21
# 3                                           virology    2025-08-19
# 4                                           virology    2025-05-14
#
#   Update time  Latest version  Versions  Number of steps  \
# 0  2025-08-28               2         2             14.0
# 1  2025-08-19               6         6             16.0
# 2  2025-08-19               4         4             11.0
# 3  2025-08-19               1         1             23.0
# 4  2025-08-19               2         2             41.0
#
#                                                Tools  \
# 0  est_abundance, kraken2, checkm2, quast, collap...
# 1  tp_cat, multiqc, ivar_variants, snpeff_sars_co...
# 2  multiqc, snpeff_sars_cov_2, picard_MarkDuplica...
# 3  qualimap_bamqc, samtools_view, snpEff, tp_cat,...
# 4  seqtk_subseq, qualimap_bamqc, samtools_view, _...
#
#                                      EDAM operations EDAM topics  \
# 0  Cross-assembly, Taxonomic classification, Stat...         NaN
# 1  Generation, Sequence alignment, Variant classi...         NaN
# 2  Generation, SNP detection, Genome indexing, Re...         NaN
# 3  Generation, Genome indexing, Read mapping, Val...         NaN
# 4  Sequence file editing, Generation, Primer remo...         NaN
#
#              License  DOI                                 Projects  To keep  \
# 0   GPL-3.0-or-later  NaN  Intergalactic Workflow Commission (IWC)     True
# 1                MIT  NaN  Intergalactic Workflow Commission (IWC)     True
# 2                MIT  NaN  Intergalactic Workflow Commission (IWC)     True
# 3  AGPL-3.0-or-later  NaN  Intergalactic Workflow Commission (IWC)     True
# 4  AGPL-3.0-or-later  NaN  Intergalactic Workflow Commission (IWC)     True
#
#    Deprecated EDAM topic single
# 0       False         Undefined
# 1       False         Undefined
# 2       False         Undefined
# 3       False         Undefined
# 4       False         Undefined

# %% [markdown]
# ## Statistics

# %%
unique_workflows = workflows_df["Name"].nunique()
unique_workflows_operations = df_inflated_workflows_operation["EDAM operation single"].nunique()
unique_workflows_topics = df_inflated_workflows_topics["EDAM topic single"].nunique()

# Print statistics
print(f"Total number of workflows: {unique_workflows}")
print(f"Total number of unique EDAM operations: {unique_workflows_operations}")
print(f"Total number of unique EDAM topics: {unique_workflows_topics}")
# Out:
# Total number of workflows: 117
# Total number of unique EDAM operations: 115
# Total number of unique EDAM topics: 9
